# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # State Capacity Dataset
# - <b>Goal</b>: Compile the state capacity dataset (Hanson) for further regression analysis
# - The dataset covers 190 countries between 1960-2015. Due to the complexity of the dataset, we do not extrapolate the values. In addition to the State Capacity values, we add the following exploratory variables:
#     - Taxes on Income % Tax Revenue
#     - Taxes on Trade % Tax Revenue
#     - Total Tax Revenue % of GDP
# - <b>Data citation</b>: Jonathan K. Hanson and Rachel Sigman, “Leviathan’s Latent Dimensions: Measuring State Capacity for Comparative Political Research.” Journal of Politics, forthcoming. https://doi.org/10.1086/715066

# %%
SC_dir = "../../data/global_Hanson_StateCapacityDataset/"

# %%
all_results = pd.read_stata(SC_dir+"StateCapacityDataset_v1.dta")
all_results
# Out:
#       cntrynum      country    year iso3 iso2  ccode scode  VDem  \
# 0          1.0  Afghanistan  1960.0  AFG   AF  700.0   AFG  36.0
# 1          1.0  Afghanistan  1961.0  AFG   AF  700.0   AFG  36.0
# 2          1.0  Afghanistan  1962.0  AFG   AF  700.0   AFG  36.0
# 3          1.0  Afghanistan  1963.0  AFG   AF  700.0   AFG  36.0
# 4          1.0  Afghanistan  1964.0  AFG   AF  700.0   AFG  36.0
# ...        ...          ...     ...  ...  ...    ...   ...   ...
# 8832     199.0  South Sudan  2011.0  SSD   SS  525.0   SSU  32.0
# 8833     199.0  South Sudan  2012.0  SSD   SS  525.0   SSU  32.0
# 8834     199.0  South Sudan  2013.0  SSD   SS  525.0   SSU  32.0
# 8835     199.0  South Sudan  2014.0  SSD   SS  525.0   SSU  32.0
# 8836     199.0  South Sudan  2015.0  SSD   SS  525.0   SSU  32.0
#
#                                     WBregion  sample_polity  ...  milexpercap  \
# 0                                 South Asia            1.0  ...     0.948857
# 1                                 South Asia            1.0  ...     0.934870
# 2                                 South Asia            1.0  ...     0.876937
# 3                                 South Asia            1.0  ...     0.936218
# 4                                 South Asia            1.0  ...     0.913283
# ...                                      ...            ...  ...          ...
# 8832  Sub-Saharan Africa (all income levels)            1.0  ...     4.682920
# 8833  Sub-Saharan Africa (all income levels)            1.0  ...     4.592208
# 8834  Sub-Saharan Africa (all income levels)            1.0  ...     4.562591
# 8835  Sub-Saharan Africa (all income levels)            1.0  ...     4.822781
# 8836  Sub-Saharan Africa (all income levels)            1.0  ...     4.686739
#
#       milpercap  policecap  StateHist50s  bti_mo  weberian    wbstat  \
# 0      2.037175        NaN      0.726306     NaN       NaN       NaN
# 1      2.564674        NaN      0.728006     NaN       NaN       NaN
# 2      2.494962        NaN      0.729685     NaN       NaN       NaN
# 3      2.527849        NaN      0.731343     NaN       NaN       NaN
# 4      2.525196        NaN      0.732981     NaN       NaN       NaN
# ...         ...        ...           ...     ...       ...       ...
# 8832   3.107348        NaN      0.599653     NaN       NaN       NaN
# 8833   2.697507        NaN      0.601541     NaN       NaN       NaN
# 8834   2.937346        NaN      0.603412     NaN       NaN  0.261111
# 8835   2.919253        NaN      0.605265     8.0       NaN  0.294444
# 8836   2.904957        NaN      0.607101     6.0       NaN  0.344445
#
#       tax_inc_tax  tax_trade_tax  taxrev_gdp
# 0             NaN            NaN         NaN
# 1             NaN            NaN         NaN
# 2             NaN            NaN         NaN
# 3             NaN            NaN         NaN
# 4             NaN            NaN         NaN
# ...           ...            ...         ...
# 8832          NaN            NaN    0.009247
# 8833          NaN            NaN    0.025273
# 8834          NaN            NaN    0.018151
# 8835          NaN            NaN    0.026940
# 8836          NaN            NaN    0.082958
#
# [8837 rows x 33 columns]

# %%
var_list = ["cntrynum","country","year","iso3","Capacity","Capacity_sd","tax_inc_tax","tax_trade_tax","taxrev_gdp"]
all_results_select = all_results[var_list]
all_results_select = all_results_select.rename(columns={"Capacity":"StateCapacity","Capacity_sd":"StateCapacity_sd"})
all_results_select = all_results_select.set_index("cntrynum")
all_results_select.to_csv("_all_temporal_state_capacity.csv")
all_results_select
# Out:
#               country    year iso3  StateCapacity  StateCapacity_sd  \
# cntrynum
# 1.0       Afghanistan  1960.0  AFG        -1.3830          0.419495
# 1.0       Afghanistan  1961.0  AFG        -1.3620          0.411242
# 1.0       Afghanistan  1962.0  AFG        -1.3690          0.411928
# 1.0       Afghanistan  1963.0  AFG        -1.3600          0.422916
# 1.0       Afghanistan  1964.0  AFG        -1.3790          0.428595
# ...               ...     ...  ...            ...               ...
# 199.0     South Sudan  2011.0  SSD        -0.8025          0.440147
# 199.0     South Sudan  2012.0  SSD        -0.9320          0.403032
# 199.0     South Sudan  2013.0  SSD        -1.4000          0.345209
# 199.0     South Sudan  2014.0  SSD        -1.4010          0.335133
# 199.0     South Sudan  2015.0  SSD        -1.3680          0.329144
#
#           tax_inc_tax  tax_trade_tax  taxrev_gdp
# cntrynum
# 1.0               NaN            NaN         NaN
# 1.0               NaN            NaN         NaN
# 1.0               NaN            NaN         NaN
# 1.0               NaN            NaN         NaN
# 1.0               NaN            NaN         NaN
# ...               ...            ...         ...
# 199.0             NaN            NaN    0.009247
# 199.0             NaN            NaN    0.025273
# 199.0             NaN            NaN    0.018151
# 199.0             NaN            NaN    0.026940
# 199.0             NaN            NaN    0.082958
#
# [8837 rows x 8 columns]
