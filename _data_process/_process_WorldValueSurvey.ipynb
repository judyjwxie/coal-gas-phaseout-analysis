# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # World Value Survey
# - <b>Goal</b>: Compile relevant variables in the World Value Survey for further regression analysis
# - The variable selected were based on searching "environment"
#     - A103 Active/Inactive membership of environmental organization (long coverage)
#     - B001 Would give part of my income for the environment
#     - B002 Increase in taxes if used to prevent environmental pollution
#     - B008 Protecting environment vs. Economic growth (long coverage)
#     - E069_14 Confidence: The Environmental Protection Movement (long coverage)
#     - S020 Year survey

# %%
all_data = pd.read_csv("../../data/global_WorldValueSurvey/WVS_TimeSeries_4_0.csv")
all_data
# Out:
#        version                    doi  S002VS  S003 COUNTRY_ALPHA  COW_NUM  \
# 0        4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# 1        4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# 2        4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# 3        4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# 4        4-0-0  doi:10.14281/18241.22       4     8           ALB      339
# ...        ...                    ...     ...   ...           ...      ...
# 450864   4-0-0  doi:10.14281/18241.22       7   909           NIR      202
# 450865   4-0-0  doi:10.14281/18241.22       7   909           NIR      202
# 450866   4-0-0  doi:10.14281/18241.22       7   909           NIR      202
# 450867   4-0-0  doi:10.14281/18241.22       7   909           NIR      202
# 450868   4-0-0  doi:10.14281/18241.22       7   909           NIR      202
#
# ...

# %%
select_data = all_data[["COUNTRY_ALPHA","S020","S017","A103","B001","B002","B008","E069_14"]]
select_data.to_csv("test.csv")

# %%
select_data.query("S020==2005").query("COUNTRY_ALPHA=='CZE'")
# Out:
# Empty DataFrame
# Columns: [COUNTRY_ALPHA, S020, S017, A103, B001, B002, B008, E069_14]
# Index: []

# %%
select_data["S020"].unique()
# Out:
# array([2002, 1998, 2014, 2005, 2018, 2011, 1997, 2006, 1999, 1995, 1991,
#        1984, 2013, 2017, 2012, 1981, 1996, 2021, 2001, 2020, 1990, 2000,
#        1982, 2007, 2019, 2022, 2009, 2004, 2016, 2010, 2003, 1989, 2008],
#       dtype=int64)
